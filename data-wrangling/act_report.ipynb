# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# #### Twitter for iPhone is the top platform for the tweets.
#
# The data set contains source column which is assumed to be the source of the device or the portal in which the tweets are made. It is interesting to visualise the value counts of each records which evaluates that twitter for iPhone is where the majority of the tweets are originated.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Confidence level of model prediction
#
# The data set contains prediction confidence column which is assumed to be predicted by a deep learning model. The prediction_1 has the highest median confidence percentage. So the Prediction_1 column has been considered for further analysis.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Favorite dog breed.
#
# From the dog breeds predicted by prediction_1 and considering the mean favorite counts. Saluki emerged top with mean favorite count 24060 and Barbancon Griffon with 885 ranked at the bottom of the table.

# %% [markdown]
# #### Popular dog names.
#
# The data set contains dog_name column which when curated and sorted we found that the Charlie is the popular dog name followed closely by Lucy, Oliver and Cooper.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Word cloud on tweets.
#
# The data set contains tweets column. We made a word cloud to find what the tweets are about. Its found that the tweets are about some one introducting the dogs with words like say, hello, meet, dog, pupper, pup, pet and rate.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Corelation between retweets and favorite counts.
#
# There is a positive corelation between retweets and favorites
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Monthly tweets.
#
# Number of tweets per month decreased over time.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Twitter engagement over months from retweet and favorite count
#
# The average retweet and favorite counts increased over time
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Favorite dog stage.
#
# Pupper followed by Doggo is the loved stages of dog based on the sum of favorite and retweet counts.
#
# ![image.png](attachment:image.png)
